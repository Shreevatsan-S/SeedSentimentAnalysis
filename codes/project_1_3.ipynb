# %%
# Import all necessary libraries
import pandas as pd
import plotly.express as px
from google.colab import files # Ensure files is imported
from sklearn.feature_extraction.text import CountVectorizer
from tabulate import tabulate # Used for cleaner output display

# %%
# Step 1: Load your data
df = pd.read_excel('seeds_sentement.xlsx')
print("DataFrame Loaded Successfully.")

# Basic EDA
print("\nDataset Head:")
print(df.head())
print("\nMissing Values:")
print(df.isnull().sum())

# Add comment length and word count features
df['comment_length'] = df['Comment'].apply(len)
df['word_count'] = df['Comment'].apply(lambda x: len(str(x).split()))

print("\nDataFrame Head with new features:")
print(df[['Comment', 'comment_length', 'word_count']].head())
# Out:
# DataFrame Loaded Successfully.
#
# Dataset Head:
#               Customer Name  Gender  \
# 0       Natraj B, Bangalore       1
# 1  Sandhya Rani, Bangalore        0
# 2        Shovan Chakraborty       1
# 3               Placeholder      -1
# 4              Vinit Ranjan       1
#
#                                              Comment    Website  \
# 0                                       good quality  Bigbasket
# 1  become black , bad smell , bad quality , old s...  Bigbasket
# 2                                               good     Amazon
# 3                                               nice     Amazon
# 4  good product , nicely packed - even check auth...   Flipkart
#
#          Seed Type       Date  Label  \
# 0    Pumpkin Seeds 2024-02-12      1
# 1  Sunflower Seeds 2024-06-11     -1
# 2       Flax Seeds 2023-08-10      0
# 3    Seasame Seeds 2024-06-30      1
# 4    Pumpkin Seeds 2024-01-29      1
#
#                                            Comment.1  Sentiment
# 0                                       good quality          1
# 1       become black bad smell bad quality old stock         -1
# 2                                               good          1
# 3                                               nice          1
# 4  good product nicely packed even check authenti...          1
#
# Missing Values:
# Customer Name    0
# Gender           0
# Comment          0
# Website          0
# Seed Type        0
# Date             0
# Label            0
# Comment.1        3
# Sentiment        0
# dtype: int64
#
# DataFrame Head with new features:
#                                              Comment  comment_length  \
# 0                                       good quality              12
# 1  become black , bad smell , bad quality , old s...              50
# 2                                               good               4
# 3                                               nice               4
# 4  good product , nicely packed - even check auth...             163
#
#    word_count
# 0           2
# 1          11
# 2           1
# 3           1
# 4          27

# %%
print("Generating Interactive Plotly Visualizations...")

# Interactive scatter plot for comment length vs word count
# This helps check for text integrity (e.g., if a high length corresponds to a high word count)
fig_scatter = px.scatter(
    df,
    x='comment_length',
    y='word_count',
    color='Label',
    title='Comment Length vs Word Count (by Label)',
    labels={'comment_length': 'Comment Length (Characters)', 'word_count': 'Word Count'},
    hover_data=['Comment']
)
fig_scatter.show()

# Interactive histogram for comment lengths
# Shows the distribution of comment sizes
fig_length = px.histogram(
    df,
    x='comment_length',
    nbins=30,
    color='Label',
    title='Distribution of Comment Lengths (by Label)',
    labels={'comment_length': 'Comment Length (Characters)'}
)
fig_length.show()

# Interactive histogram for word counts
# Shows the distribution of wordiness
fig_word_count = px.histogram(
    df,
    x='word_count',
    nbins=30,
    color='Label',
    title='Distribution of Word Counts (by Label)',
    labels={'word_count': 'Word Count'}
)
fig_word_count.show()
# Out:
# Generating Interactive Plotly Visualizations...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="b549cb46-ff99-4856-aa79-41db82889819" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b549cb46-ff99-4856-aa79-41db82889819")) {                    Plotly.newPlot(                        "b549cb46-ff99-4856-aa79-41db82889819",                        [{"customdata":[["good quality"],["become black , bad smell , bad quality , old stock"],["good"],["nice"],["good product , nicely packed - even check authenticity sending code via sm , surety adulteration.it â€™ fresh taste good . roasted oven â€™ favourite healthy munch"],["bad product"],["superfood chia"],["lesser quantity mentio ed sent"],["nice healthy used remedy"],["super quality"],["job"],["'s good produce like drink chia seed water thanks giving chia seed weight loss body ."],["good quality product must buy"],["good quality seed"],["great"],["yes good product"],["good product"],["tasty"],["appears fresh ."],["good quality pure organic seed"],["good quality"],["bitter taste ... like sesame chikki"],["good packaging . thickened paper zip lock , thus adding least plastic waste home . value money , though found impurity ."],["wow superb , liked , nice testy ."],["product fresh came good packaging , enjoy milkshake drink"],["ok quality . much fresh & crunchy seed ."],["'s really good fresh vedaka grocery shopping fresh deal product thanks amazon ."],["'s full sand .."],["seed fine first 3 month , moth grown inside packet , n't buy company folk !"],["make 7 seed roasted nd kept like mukhvas munching"],["like . require"],["good"],["good product"],["good"],["good"],["rancid bad quality"],["nice product"],["nice"],["took daughter park feed duck n't know feed bought sunflower seed started eating 'm hooked eating everyday"],["good quality.well.packed"],["got expiry date 3 month"],["food item expiry really le . people notice harmful health . minimum 6th month expiry food item"],["good quality taste"],["nice farmely company good.rahul dravid adding ."],["dust particle small stone"],["osm"],["raw much flavor like roasting good quality seed great seed cycling"],["'s clean came good packaging . everyone go . earlier bought organic brand bad . kindly go ."],["tastier"],["clean good package"],["pkt delivered much dirty n dusty ."],["clean sesame seed . good quality ."],["good taste . seems expired date product . difference high taste buy directly company . stale product ."],["grate product"],["health"],["recommend"],["'s white , rather semi white brown look . white til much available ratnadeep . pl check ."],["good"],["nice product"],["good"],["mark ... seed fresh .."],["nice"],["nice"],["good product"],["n't like 's salty"],["product genuine , seed really nice big , mean seed n't small black.this first purchase pumpkin seed 's beneficial body , ordered liked first place .."],["pic show seed absolutely coloured black dye.even innumerable soaking & washing colouring agent n't go away.god know harmful colour use.amazon must take action food adulteration racket ."],["strongly recommend buy seed . â€™ good . also request keep sell big basket ."],["good quality seed bitter yellowish"],["good product"],["day seed smell stale .they packed pouch . waste plastic jar good environment . look brand ."],["healthy much taste good skin quality good quarterly user product , vedaka keeping 's product 's goodwill sky-high ."],["good product love well properly packed"],["good quality product"],["nice"],["thanks flipkart"],["good quality product"],["good"],["product good"],["good"],["pumpkin seed ok ."],["vary nice . love"],["seed fresh . n't taste good"],["product awesome worth price .the packaging also good ."],["flax seed great dietary sup ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="40150167-39b1-49b5-aa12-2d73f34a85fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("40150167-39b1-49b5-aa12-2d73f34a85fe")) {                    Plotly.newPlot(                        "40150167-39b1-49b5-aa12-2d73f34a85fe",                        [{"bingroup":"x","hovertemplate":"Label=1\u003cbr\u003eComment Length (Characters)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1","nbinsx":30,"orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"...\...\...\...\u002fACEADAAMAAwAFwAwAAgABwARABwAYgAMABUAHAAMAAwADwAcAAwAEQAgAAYAKgBDAIMADAAmABQADAAMABQACQAHACcABAAMAL4ADAAZAAwAFgBBAAkA9gANABYAJwAEAB0ACgARABcAGAANAA0ADAARAAwAKwBgADEAFQAIACAAIwE9ABIAKwA4AB4A5gAtAA0ADACRAAsADAAZAAwAGgA+AAkA"},"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"Label=-1\u003cbr\u003eComment Length (Characters)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"-1","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"-1","nbinsx":30,"orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"...\...\..."},"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"Label=0\u003cbr\u003eComment Length (Characters)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"0","nbinsx":30,"orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"..."},"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca2 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="7c00b88d-0438-4f96-83cc-0a0290b7a6b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7c00b88d-0438-4f96-83cc-0a0290b7a6b8")) {                    Plotly.newPlot(                        "7c00b88d-0438-4f96-83cc-0a0290b7a6b8",                        [{"bingroup":"x","hovertemplate":"Label=1\u003cbr\u003eWord Count=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1","nbinsx":30,"orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"..."},"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"Label=-1\u003cbr\u003eWord Count=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"-1","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"-1","nbinsx":30,"orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"..."},"xaxis":"x","yaxis":"y","type":"histogram"},{"bingroup":"x","hovertemplate":"Label=0\u003cbr\u003eWord Count=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"0","nbinsx":30,"orientation":"v","showlegend":true,"x":{"dtype":"i1","bdata":"..."},"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type": ...

# %%
def get_ngrams(comments, n=2, top_n=20):
    """
    Calculates the frequency of the top_n n-grams (sequences of n words)
    in the provided list of comments, excluding English stop words.
    Returns a DataFrame of the top n-grams and their counts.
    """
    # Initialize the CountVectorizer with specified n-gram range and stop words
    vectorizer = CountVectorizer(ngram_range=(n, n), stop_words='english')

    # Fit and transform the comments to get n-gram counts
    ngrams = vectorizer.fit_transform(comments)

    # Sum the counts of each n-gram across all comments
    ngram_counts = ngrams.sum(axis=0)

    # Get the feature names (the actual n-grams)
    ngram_features = vectorizer.get_feature_names_out()

    # Create a DataFrame of n-grams and their counts
    ngram_df = pd.DataFrame(ngram_counts.A1, index=ngram_features, columns=['count'])

    # Sort the DataFrame by count in descending order and return the top_n results
    return ngram_df.sort_values(by='count', ascending=False).head(top_n)

# Prepare comments for N-gram analysis (handling potential NaNs)
comments = df['Comment'].astype(str).dropna()

# --- 4a. Top 20 Bigrams ---
bigrams = get_ngrams(comments, n=2, top_n=20)
print("\nTop 20 Bigrams:")
print(tabulate(bigrams, headers=bigrams.columns, tablefmt='pipe'))

# Bar plot for bigrams
fig_bigrams = px.bar(
    bigrams,
    x=bigrams.index,
    y='count',
    title='Top 20 Bigrams',
    labels={'x': 'Bigrams', 'count': 'Count'}
)
fig_bigrams.show()

# --- 4b. Top 20 Trigrams ---
trigrams = get_ngrams(comments, n=3, top_n=20)
print("\nTop 20 Trigrams:")
print(tabulate(trigrams, headers=trigrams.columns, tablefmt='pipe'))

# Bar plot for trigrams
fig_trigrams = px.bar(
    trigrams,
    x=trigrams.index,
    y='count',
    title='Top 20 Trigrams',
    labels={'x': 'Trigrams', 'count': 'Count'}
)
fig_trigrams.show()
# Out:
# Top 20 Bigrams:
# |                 |   count |
# |:----------------|--------:|
# | good quality    |     289 |
# | good product    |     229 |
# | chia seed       |     127 |
# | quality good    |      83 |
# | nice product    |      80 |
# | flax seed       |      75 |
# | quality product |      73 |
# | good taste      |      62 |
# | seed good       |      61 |
# | value money     |      59 |
# | product good    |      57 |
# | quality seed    |      54 |
# | taste good      |      46 |
# | pumpkin seed    |      43 |
# | bad quality     |      41 |
# | good health     |      40 |
# | sunflower seed  |      38 |
# | really good     |      35 |
# | poor quality    |      33 |
# | seed fresh      |      31 |
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="3a97aa44-2111-40ba-96ac-6aee3d0aa142" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3a97aa44-2111-40ba-96ac-6aee3d0aa142")) {                    Plotly.newPlot(                        "3a97aa44-2111-40ba-96ac-6aee3d0aa142",                        [{"hovertemplate":"index=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["good quality","good product","chia seed","quality good","nice product","flax seed","quality product","good taste","seed good","value money","product good","quality seed","taste good","pumpkin seed","bad quality","good health","sunflower seed","really good","poor quality","seed fresh"],"xaxis":"x","y":{"dtype":"i2","bdata":"IQHlAH8AUwBQAEsASQA+AD0AOwA5ADYALgArACkAKAAmACMAIQAfAA=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"sc ...
# Top 20 Trigrams:
# |                      |   count |
# |:---------------------|--------:|
# | good quality product |      35 |
# | good quality seed    |      26 |
# | seed good quality    |      20 |
# | organic flax seed    |      12 |
# | quality chia seed    |      12 |
# | good quality taste   |      11 |
# | sorich organic flax  |      10 |
# | element chia seed    |      10 |
# | true element chia    |      10 |
# | quality flax seed    |       9 |
# | product good quality |       9 |
# | omega fatty acid     |       8 |
# | quality seed good    |       8 |
# | good quality good    |       8 |
# | chia seed good       |       8 |
# | seed quality good    |       7 |
# | good product nice    |       7 |
# | product quality good |       7 |
# | flax seed good       |       7 |
# | good value money     |       7 |
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="b073a893-f04b-43d3-8a7d-dfbc9010d05f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b073a893-f04b-43d3-8a7d-dfbc9010d05f")) {                    Plotly.newPlot(                        "b073a893-f04b-43d3-8a7d-dfbc9010d05f",                        [{"hovertemplate":"index=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["good quality product","good quality seed","seed good quality","organic flax seed","quality chia seed","good quality taste","sorich organic flax","element chia seed","true element chia","quality flax seed","product good quality","omega fatty acid","quality seed good","good quality good","chia seed good","seed quality good","good product nice","product quality good","flax seed good","good value money"],"xaxis":"x","y":{"dtype":"i1","bdata":"IxoUDAwLCgoKCQkICAgIBwcHBwc="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"sca ...
